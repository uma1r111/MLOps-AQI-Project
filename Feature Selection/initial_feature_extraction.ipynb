# %%
import pandas as pd

# %%
# Load the full dataset
df = pd.read_csv("/content/full_preprocessed_aqi_weather_data_with_all_features.csv")

# %%
df.describe()
# Out:
#             temp_C   humidity_%  windspeed_kph    precip_mm         pm10  \
# count  2304.000000  2304.000000    2304.000000  2304.000000  2304.000000
# mean     30.943924    64.190946      17.223915     0.014149    65.495486
# std       3.103462    17.753622       8.090231     0.143310    48.515595
# min      18.000000     6.030000       0.000000     0.000000     7.000000
# 25%      29.000000    52.500000      11.900000     0.000000    37.950000
# 50%      30.200000    69.370000      16.600000     0.000000    53.400000
# 75%      33.000000    78.770000      22.300000     0.000000    77.575000
# max      40.000000   100.000000     198.400000     2.900000   385.600000
#
#              pm2_5           co          no2          so2           o3  ...  \
# count  2304.000000  2304.000000  2304.000000  2304.000000  2304.000000  ...
# mean     24.904470   314.233507    13.477604    12.708724    76.223524  ...
# std      10.264362   161.398023     9.595080     5.146719    31.833519  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2304 entries, 0 to 2303
# Data columns (total 40 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   datetime                                2304 non-null   object
#  1   temp_C                                  2304 non-null   float64
#  2   humidity_%                              2304 non-null   float64
#  3   windspeed_kph                           2304 non-null   float64
#  4   precip_mm                               2304 non-null   float64
#  5   pm10                                    2304 non-null   float64
#  6   pm2_5                                   2304 non-null   float64
#  7   co                                      2304 non-null   float64
#  8   no2                                     2304 non-null   float64
#  9   so2                                     2304 non-null   float64
# ...

# %%
# Select the specified features
selected_features = ['datetime', 'aqi_us_lag1', 'aqi_us_lag12',
                     'aqi_us_lag24', 'pm2_5', 'log_pm10', 'scaled_humidity_%',
                     'scaled_temp_C_scaled_log_windspeed_kph', 'log_so2', 'day_of_week',
                     'scaled_temp_C', 'scaled_temp_C_scaled_o3', 'log_no2', 'aqi_us']

# %%
# Extract the selected features
feature_df = df[selected_features]

# %%
feature_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2304 entries, 0 to 2303
# Data columns (total 14 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   datetime                                2304 non-null   object
#  1   aqi_us_lag1                             2304 non-null   float64
#  2   aqi_us_lag12                            2304 non-null   float64
#  3   aqi_us_lag24                            2304 non-null   float64
#  4   pm2_5                                   2304 non-null   float64
#  5   log_pm10                                2304 non-null   float64
#  6   scaled_humidity_%                       2304 non-null   float64
#  7   scaled_temp_C_scaled_log_windspeed_kph  2304 non-null   float64
#  8   log_so2                                 2304 non-null   float64
#  9   day_of_week                             2304 non-null   int64
# ...

# %%
# Save to feature_selection.csv
feature_df.to_csv("feature_selection.csv", index=False)
